# %%
import numpy as np
from IPython.display import display

my_array = np.random.randint(0, 100, size=(10, 3))
display(my_array)
# Out:
# array([[55, 34, 32],
#        [23, 18, 54],
#        [ 7, 64, 26],
#        [14, 54, 73],
#        [46, 80, 91],
#        [95, 14, 32],
#        [ 4, 24,  9],
#        [68, 59, 68],
#        [46,  6, 77],
#        [82,  2,  0]], dtype=int32)
